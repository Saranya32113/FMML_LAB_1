# %% [markdown]
# <a href="https://colab.research.google.com/github/Saranya32113/FMML_LAB_1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 10:24:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  65.2MB/s    in 1.1s
#
# 2024-05-13 10:24:21 (65.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22255  1510.06138v1  We propose a novel method for multiple cluster...  stat
# 14341  cs/9811008v1  This paper argues that an interlingual represe...    cs
# 10921  1612.08392v1  Multivariate Pattern (MVP) classification hold...  stat
# 36938  1511.05506v1  Methods of applying neural networks to control...    cs
# 39880  1707.00051v2  One of the major open challenges in self-drivi...    cs
# ...             ...                                                ...   ...
# 9653    1412.7012v4  Prior distributions of binarized natural image...  stat
# 8330   1511.06103v2  Mean-field variational inference is one of the...    cs
# 16209  1610.08694v3  We present a submission to the CogALex 2016 sh...    cs
# 39609  1610.03129v1  Extracting shape information from object bound...    cs
# 2279   1801.00085v1  Learning probability distributions on the weig...  stat
#
#                                                    title  year  \
# 22255  Multiple co-clustering based on nonparametric ...  2015
# 14341  Translating near-synonyms: Possibilities and p...  1998
# 10921  Multi-Region Neural Representation: A novel mo...  2016
# 36938                        Neurocontrol methods review  2015
# 39880  Failing to Learn: Autonomously Identifying Per...  2017
# ...                                                  ...   ...
# 9653   Boltzmann-Machine Learning of Prior Distributi...  2014
# 8330   Principled Parallel Mean-Field Inference for D...  2015
# 16209  CogALex-V Shared Task: LexNET - Integrated Pat...  2016
# 39609                                    Tangled Splines  2016
# 2279   Learning Structural Weight Uncertainty for Seq...  2017
#
#                                                 keywords
# 22255  [clustering, clustering, structure, applicable...
# 14341  [interlingual, representation, explicitly, rep...
# 10921  [multivariate, classification, potential, empl...
# 36938  [considered, described, advantages, disadvanta...
# 39880  [challenges, pedestrians, approaches, applicat...
# ...                                                  ...
# 9653   [distributions, binarized, boltzmann, accordin...
# 8330   [variational, inference, approaches, inference...
# 16209  [submission, identification, relations, integr...
# 39609  [extracting, information, applications, recogn...
# 2279   [probability, distributions, beneficial, appli...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22255    [clustering, clustering, structure, applicable...
# 14341    [interlingual, representation, explicitly, rep...
# 10921    [multivariate, classification, potential, empl...
# 36938    [considered, described, advantages, disadvanta...
# 39880    [challenges, pedestrians, approaches, applicat...
#                                ...
# 6120     [application, predicting, secondary, collected...
# 10262    [structured, regression, responses, correlated...
# 22733    [identifying, homogeneous, heterogeneous, impo...
# 19755    [independence, construct, efficient, represent...
# 22126    [dependence, equitable, relationship, differen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8803 words.
# Out of those 4595 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f65f8833-bc1c-4649-ad4b-ccc41224abd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f65f8833-bc1c-4649-ad4b-ccc41224abd7")) {                    Plotly.newPlot(                        "f65f8833-bc1c-4649-ad4b-ccc41224abd7",                        [{"x":["variational","recovering","dimensional","clustering","outperforms","available","synthetic","structures","distributions","numerical","variables","depression","biomedical","different","categorical","simultaneously","nonparametric","structure","applicable","typically","approximation","inference","multinomial","computation","inferences","distribution","heterogeneous","solutions","consisting","representation","something","explicitly","components","possibilities","translating","represent","furthermore","situation","necessary","especially","specifies","preferences","translation","generation","fluctuation","functional","decreasing","opportunity","analyzing","neuroscientists","experimental","effective","challenges","consonants","activities","anatomical","therefore","multivariate","overcoming","categories","visualizing","introduces","performance","employing","techniques","automatically","potential","smoothing","classification","advantages","described","disadvantages","considered","discussed","approaches","characterization","automated","identifying","detections","autonomous","facilitate","undetected","operation","inconsistencies","detectors","technique","autonomously","application","literature","pedestrians","particular","perception","primarily","precision","additional","sequences","analogous","applications","convergence","mechanism","continuous","optimization","algorithms","algorithm","combinatorial","segmentation","artefacts","appropriate","classical","stitching","synthesis","variation","equivalent","efficient","divergence","spatially","exhibiting","formulation","initialisation","correlations","perspectives","facilitates","structured","generalisation","architecture","criterion","significant","architectures","stability","complexity","permutation","alternative","permutations","improvements","elimination","utilities","sequential","remaining","eliminates","probabilistic","approximating","arbitrarily","introduced","marginalizing","introduce","demonstrated","challenge","iteratively","competitive","functions","integrates","framework","criticize","information","sentiment","conducted","difficult","sentiwordnet","indonesian","negativity","translated","detection","classifications","transformation","scenarios","representative","computing","measurement","procedure","approximates","compressive","developing","attractive","convolutional","experiments","computationally","completed","intensive","incorporating","autoencoder","demographic","retouching","introduction","generalized","widespread","supervised","contribution","demographics","belonging","researchers","combinations","incomplete","dictionary","reconstruction","justified","corruption","demonstrates","counterpart","thresholding","component"],"y":[53,30,172,161,276,282,132,127,115,78,141,2,18,700,25,118,22,337,47,103,107,208,5,149,13,195,21,145,55,376,12,79,91,15,13,111,158,29,84,129,7,42,97,144,1,42,6,9,55,0,328,239,126,0,41,9,163,20,11,64,11,82,901,27,366,167,135,23,526,104,89,10,131,64,451,33,100,77,19,69,37,2,38,4,44,252,8,257,127,14,272,45,22,62,134,103,7,433,127,107,92,314,588,799,44,191,5,85,99,5,49,52,55,421,26,17,8,70,1,35,13,14,102,10,234,55,244,116,40,228,7,91,4,119,17,5,73,24,3,136,18,9,132,0,321,82,165,38,125,224,28,527,1,698,37,69,148,2,2,4,16,370,10,58,92,27,126,37,109,16,11,58,29,352,592,97,7,14,64,26,7,2,30,76,11,201,58,2,13,59,30,44,64,106,12,1,51,17,18,107],"type":"bar"},{"x":["variational","recovering","dimensional","cl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4595,), (4595, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Reconstructive</span> <span style=''>Sparse</span> <span style=''>Code</span> <span style=''>Transfer</span> <span style=''>for</span> <span style=''>Contour</span> <span style='background-color:rgba(0, 255, 0, 0.6052060737527115);'>Detection</span> <span style=''>and</span> <span style=''>Semantic</span> <span style=''>Labeling</span> <br/><br/><span style=''>We</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>a</span> <span style=''>semantic</span> <span style=''>labeling</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.35897435897435903);'>reconstruction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style=''>applies</span> <span style=''>a</span> <span style=''>target</span> <span style=''>specific</span> <span style=''>learned</span> <span style=''>transfer</span> <span style=''>function</span> <span style=''>to</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>deep</span> <span style=''>sparse</span> <span style=''>code</span> <span style='background-color:rgba(0, 255, 0, 0.40560747663551416);'>representation</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>This</span> <span style=''>strategy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitions</span> <span style=''>training</span> <span style=''>into</span> <span style=''>two</span> <span style=''>distinct</span> <span style=''>stages</span> <span style=''>First</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>manner</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>generic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionaries</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>of</span> <span style=''>image</span> <span style=''>patches</span> <span style=''>We</span> <span style=''>train</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilayer</span> <span style='background-color:rgba(0, 255, 0, 0.40560747663551416);'>representation</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>pooled</span> <span style=''>codes</span> <span style=''>output</span> <span style=''>by</span> <span style=''>earlier</span> <span style=''>layers</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>encode</span> <span style=''>all</span> <span style=''>training</span> <span style=''>images</span> <span style=''>with</span> <span style=''>the</span> <span style=''>generic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionaries</span> <span style=''>and</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>transfer</span> <span style=''>function</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizes</span> <span style='background-color:rgba(0, 255, 0, 0.35897435897435903);'>reconstruction</span> <span style=''>of</span> <span style=''>patches</span> <span style='background-color:rgba(0, 255, 0, 0.574468085106383);'>extracted</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.8400000000000001);'>annotated</span> <span style=''>ground</span> <span style=''>truth</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Single</span> <span style=''>Index</span> <span style=''>Models</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensions</span> <br/><br/><span style=''>Single</span> <span style=''>Index</span> <span style=''>Models</span> <span style=''>(SIMs)</span> <span style=''>are</span> <span style=''>simple</span> <span style=''>yet</span> <span style=''>flexible</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>Response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style=''>function</span> <span style=''>of</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>in</span> <span style=''>this</span> <span style=''>context</span> <span style=''>requires</span> <span style=''>learning</span> <span style=''>both</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>function</span> <span style=''>While</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>SIMs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>regime</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>learn</span> <span style=''>SIMs</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forthcoming</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>three</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>SIM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style=''>validate</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Zeroth</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asynchronous</span> <span style=''>Doubly</span> <span style='background-color:rgba(255, 0, 0, 0.3063291139240506);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>Variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <br/><br/><span style=''>Zeroth</span> <span style=''>order</span> <span style=''>(derivative</span> <span style=''>free)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>attracts</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.38983050847457634);'>attention</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>because</span> <span style=''>explicit</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>calculations</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>infeasible</span> <span style=''>To</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>both</span> <span style=''>in</span> <span style=''>volume</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3116279069767442);'>dimension</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asynchronous</span> <span style=''>doubly</span> <span style='background-color:rgba(255, 0, 0, 0.3063291139240506);'>stochastic</span> <span style=''>zeroth</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>were</span> <span style=''>proposed</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asynchronous</span> <span style=''>doubly</span> <span style='background-color:rgba(255, 0, 0, 0.3063291139240506);'>stochastic</span> <span style=''>zeroth</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>O(frac1sqrtT)</span> <span style=''>(also</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3063291139240506);'>stochastic</span> <span style=''>zeroth</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>algorithms)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>finite</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>smooth</span> <span style=''>but</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>necessarily</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asynchronous</span> <span style=''>doubly</span> <span style='background-color:rgba(255, 0, 0, 0.3063291139240506);'>stochastic</span> <span style=''>zeroth</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Multi</span> <span style=''>Plate</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compounds</span> <br/><br/><span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>(chemicals)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>part</span> <span style=''>of</span> <span style=''>drug</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thousands</span> <span style=''>to</span> <span style=''>millions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>with</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>hits</span> <span style=''>Most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>tools</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>industry</span> <span style=''>standard</span> <span style=''>B</span> <span style=''>score</span> <span style=''>method</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>compound</span> <span style=''>plates</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>exploit</span> <span style=''>cross</span> <span style=''>plate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>strength</span> <span style=''>among</span> <span style=''>plates</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>modeling</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>hits</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>plates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>sharing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>strength</span> <span style=''>among</span> <span style=''>plates</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>more</span> <span style=''>robus ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.052310999641705484)
# 	knowledge (0.12396990326048012)
# 	different (0.2508061626657112)
# 	segmentation (0.06843425295592978)
# 	processing (0.10713006091006808)
# 	information (0.25008957362952344)
# 	representation (0.13471873880329632)
# 	convolutional (0.12611967036904334)
# 	detection (0.13256897169473308)
# 	recognition (0.13436044428520244)
#
# Some Statistics words are:
# 	stochastic (0.12842210054753608)
# 	variables (0.13937282229965156)
# 	algorithm (0.3758088601294176)
# 	theoretical (0.1493280238924838)
# 	statistical (0.16177202588352413)
# 	distribution (0.17322050771528125)
# 	estimation (0.17222498755599802)
# 	inference (0.19313091090094575)
# 	dimensional (0.1831757093081135)
# 	regression (0.16973618715778996)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e41ead16-ab31-462f-883f-abee21368ac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e41ead16-ab31-462f-883f-abee21368ac0")) {                    Plotly.newPlot(                        "e41ead16-ab31-462f-883f-abee21368ac0",                        [{"x":["variational","recovering","dimensional","clustering","outperforms","available","synthetic","structures","distributions","numerical","variables","depression","biomedical","different","categorical","simultaneously","nonparametric","structure","applicable","typically","approximation","inference","multinomial","computation","inferences","distribution","heterogeneous","solutions","consisting","representation","something","explicitly","components","possibilities","translating","represent","furthermore","situation","necessary","especially","specifies","preferences","translation","generation","fluctuation","functional","decreasing","opportunity","analyzing","neuroscientists","experimental","effective","challenges","consonants","activities","anatomical","therefore","multivariate","overcoming","categories","visualizing","introduces","performance","employing","techniques","automatically","potential","smoothing","classification","advantages","described","disadvantages","considered","discussed","approaches","characterization","automated","identifying","detections","autonomous","facilitate","undetected","operation","inconsistencies","detectors","technique","autonomously","application","literature","pedestrians","particular","perception","primarily","precision","additional","sequences","analogous","applications","convergence","mechanism","continuous","optimization","algorithms","algorithm","combinatorial","segmentation","artefacts","appropriate","classical","stitching","synthesis","variation","equivalent","efficient","divergence","spatially","exhibiting","formulation","initialisation","correlations","perspectives","facilitates","structured","generalisation","architecture","criterion","significant","architectures","stability","complexity","permutation","alternative","permutations","improvements","elimination","utilities","sequential","remaining","eliminates","probabilistic","approximating","arbitrarily","introduced","marginalizing","introduce","demonstrated","challenge","iteratively","competitive","functions","integrates","framework","criticize","information","sentiment","conducted","difficult","sentiwordnet","indonesian","negativity","translated","detection","classifications","transformation","scenarios","representative","computing","measurement","procedure","approximates","compressive","developing","attractive","convolutional","experiments","computationally","completed","intensive","incorporating","autoencoder","demographic","retouching","introduction","generalized","widespread","supervised","contribution","demographics","belonging","researchers","combinations","incomplete","dictionary","reconstruction","justified","corruption","demonstrates","counterpart","thresholding","component","theoretically","inpainting","iterative","vulnerable","relatively","posterior","adaptation","expectation","significantly","unlabeled","rightarrow","outperform","contributions","propagation","straightforward","maximization","challenging","adversarial","correspondence","unsupervised","attention","improvement","knowledge","accumulation","discriminative","activations","insensitive","transfers","advantage","calculate","deviation","representations","connected","alignment","particularly","implicitly","amortised","randomness","producing","initialise","including","realistic","approximations","generative","intractable","approximate","modelling","improving","densities","coordinate","probability","successfully","i ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	neuroscientists
# 	consonants
# 	marginalizing
# 	initialise
# 	timeseries
# 	assertion
# 	discretizing
# 	impressively
# 	overestimate
# 	chemometrics
# 	distributionally
# 	pediatric
# 	interventions
# 	discharge
# 	physiologic
# 	definiteness
# 	framelets
# 	emphmulti
# 	repeatmulti
# 	penalization
# Some words which never appear in Statistics papers:
# 	undetected
# 	inconsistencies
# 	autonomously
# 	sentiwordnet
# 	indonesian
# 	retouching
# 	demographics
# 	nonextensive
# 	traceability
# 	transformer
# 	magnification
# 	observers
# 	affordance
# 	photometric
# 	homography
# 	unpleasant
# 	egocentric
# 	peripheral
# 	protrusions
# 	interview

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076449776957391e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
